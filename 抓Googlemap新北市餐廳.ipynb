# %%
'''
匯入套件
'''
'''
匯入工具
'''
import pyautogui
from time import sleep, time 
import keyboard
from IPython.display import clear_output
# 操作 browser 的 API
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains

# 處理逾時例外的工具
from selenium.common.exceptions import TimeoutException

# 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support.ui import WebDriverWait

# 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 強制等待 (執行期間休息一下)
from time import sleep

# 整理 json 使用的工具
import json

# 執行 command 的時候用的
import os

import pandas as pd


'''=   == 
selenium 啓動 Chrome 的進階配置參數
參考網址：https://stackoverflow.max-everyday.com/2019/12/selenium-chrome-options/
'''
# 啟動瀏覽器工具的選項
# my_options = webdriver.ChromeOptions()
# # my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
# #my_options.add_argument("--start-maximized")         #最大化視窗
# my_options.add_argument("--incognito")               #開啟無痕模式
# my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
# my_options.add_argument("--disable-notifications")  #取消 chrome 推播通知
# my_options.add_argument("--lang=zh-TW")  #設定為正體中文

#在無痕模式下增加擴充功能 C:<--是CRX的檔案位置 但重點是要先把擴充功能的公鑰私鑰搞出來
chrome_options = webdriver.ChromeOptions()
chrome_options.add_extension('C://dataimport//1.0.8_0.crx')
driver = webdriver.Chrome(chrome_options=chrome_options)


# 使用 Chrome 的 WebDriver
# my_service = Service(executable_path="./chromedriver.exe")

# driver = webdriver.Chrome(
#     options = my_options,
#     service = my_service
# )
pf1 = pd.read_json('cityroad/新北市區名.json')
roads = pd.DataFrame(pf1)
road = roads
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_12244\3299574090.py:56: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=chrome_options)

# %%
for i in road[0]:
    driver.get('https://www.google.com/search')
    try :
        inputElement = driver.find_element(By.CSS_SELECTOR, 'input[class="gLFyf"]')
    except :
        inputElement = driver.find_element(By.CSS_SELECTOR, 'input[class="gLFyf gsfi"]')
    pass
    
    
    inputElement.clear()
    sleep(0.5)
    inputElement.send_keys('新北市' +i+'餐廳')
    inputElement.submit()
    try:
        cssSelectorBtn = "#Odp5De > div > div > div.VT5Tde > div.kuydt > div.iNTie > g-more-link > a > div > span.wUrVib.OSrXXb"
        btn = driver.find_element(By.CSS_SELECTOR, cssSelectorBtn)
        btn.click()
        sleep(2)

        pyautogui.PAUSE = 2
        btn_0_location = pyautogui.locateOnScreen('restaurant/2.png', confidence=0.8)
        btn_0_point = pyautogui.center(btn_0_location)
        pyautogui.click(btn_0_point.x, btn_0_point.y)
        sleep(2)
        btn_1_location = pyautogui.locateOnScreen('restaurant/1.png', confidence=0.8)
        btn_1_point = pyautogui.center(btn_1_location)
        pyautogui.click(btn_1_point.x, btn_1_point.y)
        sleep(2)

        window_before = driver.window_handles[0]
        window_after = driver.window_handles[1]
        driver.switch_to.window(window_after)
        try:
            WebDriverWait(driver, 5).until(
                EC.presence_of_element_located( 
                    (By.ID, 'nextButton') 
                )
            ).click()
        except:
            WebDriverWait(driver, 5).until(
                EC.presence_of_element_located( 
                    (By.ID, 'startScraping') 
                )
            ).click()
        pass

        sleep(1)

        window_before = driver.window_handles[0]
        window_after = driver.window_handles[1]
        driver.switch_to.window(window_before)

        try : 
            nextpage = driver.find_element(By.CSS_SELECTOR,'#pnnext > span:nth-child(2)')
            nextpage.click()
            sleep(1)
        except:
            pass
            # 切換視窗
        window_before = driver.window_handles[0]
        window_after = driver.window_handles[1]
        driver.switch_to.window(window_after)
        sleep(2)

    #     btn_4_location = pyautogui.locateOnScreen('images/start.png', confidence=0.8)
    #     btn_4_point = pyautogui.center(btn_4_location)
    #     pyautogui.click(btn_4_point.x, btn_4_point.y)
        sleep(40)

        save = driver.find_element(By.CSS_SELECTOR,'div[class="col-xs-3"]> button#xlsx')
        save.click()
        sleep(1)
    #     btn_5_location = pyautogui.locateOnScreen('images/save.png', confidence=0.9)
    #     btn_5_point = pyautogui.center(btn_5_location)
    #     pyautogui.click(btn_5_point.x, btn_5_point.y)
    #     sleep(3)

        driver.close()

    #    window_before = driver.window_handles[0]
    #     window_after = driver.window_handles[1]
        window_origin = driver.window_handles[-1]
        driver.switch_to.window(window_origin)
    #     sleep(2)
    except:
        pass
